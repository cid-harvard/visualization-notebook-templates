# %% [markdown]
# # Atlas of Economic Complexity: growth predictions data processing and visualizations
#
# Methodological notes, data sources and interactive visualization from http://atlas.cid.harvard.edu/rankings/growth-predictions/
#
# Related links
# * [U.N. Comtrade](http://comtrade.un.org) source of trade data
# * [Atlas Data](https://github.com/cid-harvard/atlas-data) processing scripts for trade data

# %%
# Required modules to run this notebook
from IPython.display import IFrame
import pandas as pd

# %%
# Raw data files
file_projections = 'sourceData/Growth_proj_rankings_2014.csv'
file_rank_eci = 'sourceData/ECI_rankings_2014.csv'
url_countries = 'https://raw.githubusercontent.com/mledoze/countries/master/dist/countries.json'

# %% [markdown]
# # Load countries metadata

# %%
import json
import urllib

r = urllib.request.urlopen(url_countries)
data = json.loads(r.read().decode(r.info().get_param('charset') or 'utf-8'))

# %%
# Flatten the countries dataset
from pandas.io.json import json_normalize
result = json_normalize(data)

# %%
df_countries = pd.DataFrame(result)
df_countries.head()
# Out:
#                                       altSpellings     area  \
# 0                                             [AW]      180
# 1                                 [AF, Afġānistān]   652230
# 2  [AO, República de Angola, ʁɛpublika de an'ɡɔla]  1246700
# 3                                             [AI]       91
# 4                  [AX, Aaland, Aland, Ahvenanmaa]     1580
#
#                           borders callingCode     capital cca2 cca3 ccn3 cioc  \
# 0                              []       [297]  Oranjestad   AW  ABW  533  ARU
# 1  [IRN, PAK, TKM, UZB, TJK, CHN]        [93]       Kabul   AF  AFG  004  AFG
# 2            [COG, COD, ZMB, NAM]       [244]      Luanda   AO  AGO  024  ANG
# 3                              []      [1264]  The Valley   AI  AIA  660
# 4                              []       [358]   Mariehamn   AX  ALA  248
#
#   currency                ...                translations.jpn.common  \
# 0    [AWG]                ...                                    アルバ
# 1    [AFN]                ...                                アフガニスタン
# 2    [AOA]                ...                                   アンゴラ
# 3    [XCD]                ...                                   アンギラ
# 4    [EUR]                ...                                オーランド諸島
#
#   translations.jpn.official translations.nld.common  \
# 0                       アルバ                   Aruba
# 1           アフガニスタン·イスラム共和国             Afghanistan
# 2                   アンゴラ共和国                  Angola
# 3                     アングィラ                Anguilla
# 4                   オーランド諸島           Ålandeilanden
#
#             translations.nld.official translations.por.common  \
# 0                               Aruba                   Aruba
# 1  Islamitische Republiek Afghanistan             Afeganistão
# 2                    Republiek Angola                  Angola
# 3                            Anguilla                Anguilla
# 4                      Åland eilanden                 Alândia
#
#            translations.por.official translations.rus.common  \
# 0                              Aruba                   Аруба
# 1  República Islâmica do Afeganistão              Афганистан
# 2                República de Angola                  Ангола
# 3                           Anguilla                 Ангилья
# 4                        Ilhas Åland       Аландские острова
#
#          translations.rus.official translations.spa.common  \
# 0                            Аруба                   Aruba
# 1  Исламская Республика Афганистан              Afganistán
# 2                Республика Ангола                  Angola
# 3                          Ангилья                Anguilla
# 4                Аландские острова                 Alandia
#
#           translations.spa.official
# 0                             Aruba
# 1  República Islámica de Afganistán
# 2               República de Angola
# 3                           Anguila
# 4                       Islas Åland
#
# [5 rows x 509 columns]

# %% [markdown]
# # Load growth prediction data

# %%
# Loading projections data
df = pd.read_csv(file_projections)

# %%
# Removing ranking column (will be re-generated later on)
df.pop('rank2014');
df.pop('countryname');

# %%
# Turning temporal columns into rows with a column header called 'year'
df = pd.melt(df, id_vars=["iso"], var_name="year", value_name="value")

# %%
df.head()
# Out:
#    iso    year  value
# 0  IND  tg2004   7.15
# 1  UGA  tg2004   6.11
# 2  KEN  tg2004   6.32
# 3  TZA  tg2004   6.11
# 4  EGY  tg2004   5.00

# %%
# Formatting year (time) column by removing the first two chars
for index, row in df.iterrows():
    df.loc[index, "year"] = df.loc[index, "year"][2:]

# %%
# Do we have any missing data point? (e.g. value is NaN)
df[df['value'].isnull()]
# Out:
#       iso  year  value
# 38    SRB  2004    NaN
# 614   SYR  2008    NaN
# 737   SYR  2009    NaN
# 860   SYR  2010    NaN
# 983   SYR  2011    NaN
# 1106  SYR  2012    NaN
# 1229  SYR  2013    NaN
# 1352  SYR  2014    NaN

# %%
# Find country names with missing data points
countries_null = list(set(df[df['value'].isnull()]['iso']))

# %%
list(df.iso)
# Out:
# ['IND',
#  'UGA',
#  'KEN',
#  'TZA',
#  'EGY',
#  'MDG',
#  'SEN',
#  'PHL',
#  'MWI',
#  'ZMB',
#  'GTM',
#  'PAK',
#  'ZWE',
#  'MYS',
#  'IDN',
#  'JOR',
#  'VNM',
#  'MLI',
#  'THA',
#  'TUR',
#  'MOZ',
#  'GIN',
#  'ETH',
#  'MEX',
#  'CMR',
#  'HND',
#  'CHN',
#  'YEM',
#  'CIV',
#  'ISR',
#  'KGZ',
#  'TUN',
#  'GHA',
#  'KHM',
#  'KOR',
#  'ZAF',
#  'TJK',
#  'UZB',
#  'SRB',
#  'LKA',
#  'PRY',
#  'UKR',
#  'ESP',
#  'ROM',
#  'BIH',
#  'SVK',
#  'SLV',
#  'MRT',
#  'PNG',
#  'BRA',
#  'HUN',
#  'BLR',
#  'BGD',
#  'POL',
#  'GBR',
#  'BGR',
#  'EST',
#  'CHE',
#  'PRT',
#  'CZE',
#  'SVN',
#  'IRL',
#  'NIC',
#  'DOM',
#  'FIN',
#  'MAR',
#  'NGA',
#  'LBN',
#  'COL',
#  'HRV',
#  'LTU',
#  'LAO',
#  'CRI',
#  'BOL',
#  'COG',
#  'ARG',
#  'GRC',
#  'PER',
#  'FRA',
#  'LVA',
#  'MDA',
#  'SWE',
#  'CAN',
#  'BEL',
#  'USA',
#  'NLD',
#  'NAM',
#  'DNK',
#  'JPN',
#  'AGO',
#  'MNG',
#  'URY',
#  'MUS',
#  'KAZ',
#  'SAU',
#  'OMN',
#  'ARE',
#  'NZL',
#  'RUS',
#  'IRN',
#  'KWT',
#  'MKD',
#  'JAM',
#  'ECU',
#  'CHL',
#  'GAB',
#  'TKM',
#  'ITA',
#  'ALB',
#  'GEO',
#  'NOR',
#  'DZA',
#  'VEN',
#  'AUT',
#  'AZE',
#  'BWA',
#  'QAT',
#  'AUS',
#  'LBY',
#  'CUB',
#  'DEU',
#  'TTO',
#  'SYR',
#  'IND',
#  'UGA',
#  'KEN',
#  'TZA',
#  'EGY',
#  'MDG',
#  'SEN',
#  'PHL',
#  'MWI',
#  'ZMB',
#  'GTM',
#  'PAK',
#  'ZWE',
#  'MYS',
#  'IDN',
#  'JOR',
#  'VNM',
#  'MLI',
#  'THA',
#  'TUR',
#  'MOZ',
#  'GIN',
#  'ETH',
#  'MEX',
#  'CMR',
#  'HND',
#  'CHN',
#  'YEM',
#  'CIV',
#  'ISR',
#  'KGZ',
#  'TUN',
#  'GHA',
#  'KHM',
#  'KOR',
#  'ZAF',
#  'TJK',
#  'UZB',
#  'SRB',
#  'LKA',
#  'PRY',
#  'UKR',
#  'ESP',
#  'ROM',
#  'BIH',
#  'SVK',
#  'SLV',
#  'MRT',
#  'PNG',
#  'BRA',
#  'HUN',
#  'BLR',
#  'BGD',
#  'POL',
#  'GBR',
#  'BGR',
#  'EST',
#  'CHE',
#  'PRT',
#  'CZE',
#  'SVN',
#  'IRL',
#  'NIC',
#  'DOM',
#  'FIN',
#  'MAR',
#  'NGA',
#  'LBN',
#  'COL',
#  'HRV',
#  'LTU',
#  'LAO',
#  'CRI',
#  'BOL',
#  'COG',
#  'ARG',
#  'GRC',
#  'PER',
#  'FRA',
#  'LVA',
#  'MDA',
#  'SWE',
#  'CAN',
#  'BEL',
#  'USA',
#  'NLD',
#  'NAM',
#  'DNK',
#  'JPN',
#  'AGO',
#  'MNG',
#  'URY',
#  'MUS',
#  'KAZ',
#  'SAU',
#  'OMN',
#  'ARE',
#  'NZL',
#  'RUS',
#  'IRN',
#  'KWT',
#  'MKD',
#  'JAM',
#  'ECU',
#  'CHL',
#  'GAB',
#  'TKM',
#  'ITA',
#  'ALB',
#  'GEO',
#  'NOR',
#  'DZA',
#  'VEN',
#  'AUT',
#  'AZE',
#  'BWA',
#  'QAT',
#  'AUS',
#  'LBY',
#  'CUB',
#  'DEU',
#  'TTO',
#  'SYR',
#  'IND',
#  'UGA',
#  'KEN',
#  'TZA',
#  'EGY',
#  'MDG',
#  'SEN',
#  'PHL',
#  'MWI',
#  'ZMB',
#  'GTM',
#  'PAK',
#  'ZWE',
#  'MYS',
#  'IDN',
#  'JOR',
#  'VNM',
#  'MLI',
#  'THA',
#  'TUR',
#  'MOZ',
#  'GIN',
#  'ETH',
#  'MEX',
#  'CMR',
#  'HND',
#  'CHN',
#  'YEM',
#  'CIV',
#  'ISR',
#  'KGZ',
#  'TUN',
#  'GHA',
#  'KHM',
#  'KOR',
#  'ZAF',
#  'TJK',
#  'UZB',
#  'SRB',
#  'LKA',
#  'PRY',
#  'UKR',
#  'ESP',
#  'ROM',
#  'BIH',
#  'SVK',
#  'SLV',
#  'MRT',
#  'PNG',
#  'BRA',
#  'HUN',
#  'BLR',
#  'BGD',
#  'POL',
#  'GBR',
#  'BGR',
#  'EST',
#  'CHE',
#  'PRT',
#  'CZE',
#  'SVN',
#  'IRL',
#  'NIC',
#  'DOM',
#  'FIN',
#  'MAR',
#  'NGA',
#  'LBN',
#  'COL',
#  'HRV',
#  'LTU',
#  'LAO',
#  'CRI',
#  'BOL',
#  'COG',
#  'ARG',
#  'GRC',
#  'PER',
#  'FRA',
#  'LVA',
#  'MDA',
#  'SWE',
#  'CAN',
#  'BEL',
#  'USA',
#  'NLD',
#  'NAM',
#  'DNK',
#  'JPN',
#  'AGO',
#  'MNG',
#  'URY',
#  'MUS',
#  'KAZ',
#  'SAU',
#  'OMN',
#  'ARE',
#  'NZL',
#  'RUS',
#  'IRN',
#  'KWT',
#  'MKD',
#  'JAM',
#  'ECU',
#  'CHL',
#  'GAB',
#  'TKM',
#  'ITA',
#  'ALB',
#  'GEO',
#  'NOR',
#  'DZA',
#  'VEN',
#  'AUT',
#  'AZE',
#  'BWA',
#  'QAT',
#  'AUS',
#  'LBY',
#  'CUB',
#  'DEU',
#  'TTO',
#  'SYR',
#  'IND',
#  'UGA',
#  'KEN',
#  'TZA',
#  'EGY',
#  'MDG',
#  'SEN',
#  'PHL',
#  'MWI',
#  'ZMB',
#  'GTM',
#  'PAK',
#  'ZWE',
#  'MYS',
#  'IDN',
#  'JOR',
#  'VNM',
#  'MLI',
#  'THA',
#  'TUR',
#  'MOZ',
#  'GIN',
#  'ETH',
#  'MEX',
#  'CMR',
#  'HND',
#  'CHN',
#  'YEM',
#  'CIV',
#  'ISR',
#  'KGZ',
#  'TUN',
#  'GHA',
#  'KHM',
#  'KOR',
#  'ZAF',
#  'TJK',
#  'UZB',
#  'SRB',
#  'LKA',
#  'PRY',
#  'UKR',
#  'ESP',
#  'ROM',
#  'BIH',
#  'SVK',
#  'SLV',
#  'MRT',
#  'PNG',
#  'BRA',
#  'HUN',
#  'BLR',
#  'BGD',
#  'POL',
#  'GBR',
#  'BGR',
#  'EST',
#  'CHE',
#  'PRT',
#  'CZE',
#  'SVN',
#  'IRL',
#  'NIC',
#  'DOM',
#  'FIN',
#  'MAR',
#  'NGA',
#  'LBN',
#  'COL',
#  'HRV',
#  'LTU',
#  'LAO',
#  'CRI',
#  'BOL',
#  'COG',
#  'ARG',
#  'GRC',
#  'PER',
#  'FRA',
#  'LVA',
#  'MDA',
#  'SWE',
#  'CAN',
#  'BEL',
#  'USA',
#  'NLD',
#  'NAM',
#  'DNK',
#  'JPN',
#  'AGO',
#  'MNG',
#  'URY',
#  'MUS',
#  'KAZ',
#  'SAU',
#  'OMN',
#  'ARE',
#  'NZL',
#  'RUS',
#  'IRN',
#  'KWT',
#  'MKD',
#  'JAM',
#  'ECU',
#  'CHL',
#  'GAB',
#  'TKM',
#  'ITA',
#  'ALB',
#  'GEO',
#  'NOR',
#  'DZA',
#  'VEN',
#  'AUT',
#  'AZE',
#  'BWA',
#  'QAT',
#  'AUS',
#  'LBY',
#  'CUB',
#  'DEU',
#  'TTO',
#  'SYR',
#  'IND',
#  'UGA',
#  'KEN',
#  'TZA',
#  'EGY',
#  'MDG',
#  'SEN',
#  'PHL',
#  'MWI',
#  'ZMB',
#  'GTM',
#  'PAK',
#  'ZWE',
#  'MYS',
#  'IDN',
#  'JOR',
#  'VNM',
#  'MLI',
#  'THA',
#  'TUR',
#  'MOZ',
#  'GIN',
#  'ETH',
#  'MEX',
#  'CMR',
#  'HND',
#  'CHN',
#  'YEM',
#  'CIV',
#  'ISR',
#  'KGZ',
#  'TUN',
#  'GHA',
#  'KHM',
#  'KOR',
#  'ZAF',
#  'TJK',
#  'UZB',
#  'SRB',
#  'LKA',
#  'PRY',
#  'UKR',
#  'ESP',
#  'ROM',
#  'BIH',
#  'SVK',
#  'SLV',
#  'MRT',
#  'PNG',
#  'BRA',
#  'HUN',
#  'BLR',
#  'BGD',
#  'POL',
#  'GBR',
#  'BGR',
#  'EST',
#  'CHE',
#  'PRT',
#  'CZE',
#  'SVN',
#  'IRL',
#  'NIC',
#  'DOM',
#  'FIN',
#  'MAR',
#  'NGA',
#  'LBN',
#  'COL',
#  'HRV',
#  'LTU',
#  'LAO',
#  'CRI',
#  'BOL',
#  'COG',
#  'ARG',
#  'GRC',
#  'PER',
#  'FRA',
#  'LVA',
#  'MDA',
#  'SWE',
#  'CAN',
#  'BEL',
#  'USA',
#  'NLD',
#  'NAM',
#  'DNK',
#  'JPN',
#  'AGO',
#  'MNG',
#  'URY',
#  'MUS',
#  'KAZ',
#  'SAU',
#  'OMN',
#  'ARE',
#  'NZL',
#  'RUS',
#  'IRN',
#  'KWT',
#  'MKD',
#  'JAM',
#  'ECU',
#  'CHL',
#  'GAB',
#  'TKM',
#  'ITA',
#  'ALB',
#  'GEO',
#  'NOR',
#  'DZA',
#  'VEN',
#  'AUT',
#  'AZE',
#  'BWA',
#  'QAT',
#  'AUS',
#  'LBY',
#  'CUB',
#  'DEU',
#  'TTO',
#  'SYR',
#  'IND',
#  'UGA',
#  'KEN',
#  'TZA',
#  'EGY',
#  'MDG',
#  'SEN',
#  'PHL',
#  'MWI',
#  'ZMB',
#  'GTM',
#  'PAK',
#  'ZWE',
#  'MYS',
#  'IDN',
#  'JOR',
#  'VNM',
#  'MLI',
#  'THA',
#  'TUR',
#  'MOZ',
#  'GIN',
#  'ETH',
#  'MEX',
#  'CMR',
#  'HND',
#  'CHN',
#  'YEM',
#  'CIV',
#  'ISR',
#  'KGZ',
#  'TUN',
#  'GHA',
#  'KHM',
#  'KOR',
#  'ZAF',
#  'TJK',
#  'UZB',
#  'SRB',
#  'LKA',
#  'PRY',
#  'UKR',
#  'ESP',
#  'ROM',
#  'BIH',
#  'SVK',
#  'SLV',
#  'MRT',
#  'PNG',
#  'BRA',
#  'HUN',
#  'BLR',
#  'BGD',
#  'POL',
#  'GBR',
#  'BGR',
#  'EST',
#  'CHE',
#  'PRT',
#  'CZE',
#  'SVN',
#  'IRL',
#  'NIC',
#  'DOM',
#  'FIN',
#  'MAR',
#  'NGA',
#  'LBN',
#  'COL',
#  'HRV',
#  'LTU',
#  'LAO',
#  'CRI',
#  'BOL',
#  'COG',
#  'ARG',
#  'GRC',
#  'PER',
#  'FRA',
#  'LVA',
#  'MDA',
#  'SWE',
#  'CAN',
#  'BEL',
#  'USA',
#  'NLD',
#  'NAM',
#  'DNK',
#  'JPN',
#  'AGO',
#  'MNG',
#  'URY',
#  'MUS',
#  'KAZ',
#  'SAU',
#  'OMN',
#  'ARE',
#  'NZL',
#  'RUS',
#  'IRN',
#  'KWT',
#  'MKD',
#  'JAM',
#  'ECU',
#  'CHL',
#  'GAB',
#  'TKM',
#  'ITA',
#  'ALB',
#  'GEO',
#  'NOR',
#  'DZA',
#  'VEN',
#  'AUT',
#  'AZE',
#  'BWA',
#  'QAT',
#  'AUS',
#  'LBY',
#  'CUB',
#  'DEU',
#  'TTO',
#  'SYR',
#  'IND',
#  'UGA',
#  'KEN',
#  'TZA',
#  'EGY',
#  'MDG',
#  'SEN',
#  'PHL',
#  'MWI',
#  'ZMB',
#  'GTM',
#  'PAK',
#  'ZWE',
#  'MYS',
#  'IDN',
#  'JOR',
#  'VNM',
#  'MLI',
#  'THA',
#  'TUR',
#  'MOZ',
#  'GIN',
#  'ETH',
#  'MEX',
#  'CMR',
#  'HND',
#  'CHN',
#  'YEM',
#  'CIV',
#  'ISR',
#  'KGZ',
#  'TUN',
#  'GHA',
#  'KHM',
#  'KOR',
#  'ZAF',
#  'TJK',
#  'UZB',
#  'SRB',
#  'LKA',
#  'PRY',
#  'UKR',
#  'ESP',
#  'ROM',
#  'BIH',
#  'SVK',
#  'SLV',
#  'MRT',
#  'PNG',
#  'BRA',
#  'HUN',
#  'BLR',
#  'BGD',
#  'POL',
#  'GBR',
#  'BGR',
#  'EST',
#  'CHE',
#  'PRT',
#  'CZE',
#  'SVN',
#  'IRL',
#  'NIC',
#  'DOM',
#  'FIN',
#  'MAR',
#  'NGA',
#  'LBN',
#  'COL',
#  'HRV',
#  'LTU',
#  'LAO',
#  'CRI',
#  'BOL',
#  'COG',
#  'ARG',
#  'GRC',
#  'PER',
#  'FRA',
#  'LVA',
#  'MDA',
#  'SWE',
#  'CAN',
#  'BEL',
#  'USA',
#  'NLD',
#  'NAM',
#  'DNK',
#  'JPN',
#  'AGO',
#  'MNG',
#  'URY',
#  'MUS',
#  'KAZ',
#  'SAU',
#  'OMN',
#  'ARE',
#  'NZL',
#  'RUS',
#  'IRN',
#  'KWT',
#  'MKD',
#  'JAM',
#  'ECU',
#  'CHL',
#  'GAB',
#  'TKM',
#  'ITA',
#  'ALB',
#  'GEO',
#  'NOR',
#  'DZA',
#  'VEN',
#  'AUT',
#  'AZE',
#  'BWA',
#  'QAT',
#  'AUS',
#  'LBY',
#  'CUB',
#  'DEU',
#  'TTO',
#  'SYR',
#  'IND',
#  'UGA',
#  'KEN',
#  'TZA',
#  'EGY',
#  'MDG',
#  'SEN',
#  'PHL',
#  'MWI',
#  'ZMB',
#  'GTM',
#  'PAK',
#  'ZWE',
#  'MYS',
#  'IDN',
#  'JOR',
#  'VNM',
#  'MLI',
#  'THA',
#  'TUR',
#  'MOZ',
#  'GIN',
#  'ETH',
#  'MEX',
#  'CMR',
#  'HND',
#  'CHN',
#  'YEM',
#  'CIV',
#  'ISR',
#  'KGZ',
#  'TUN',
#  'GHA',
#  'KHM',
#  'KOR',
#  'ZAF',
#  'TJK',
#  'UZB',
#  'SRB',
#  'LKA',
#  'PRY',
#  'UKR',
#  'ESP',
#  'ROM',
#  'BIH',
#  'SVK',
#  'SLV',
#  'MRT',
#  'PNG',
#  'BRA',
#  'HUN',
#  'BLR',
#  'BGD',
#  'POL',
#  'GBR',
#  'BGR',
#  'EST',
#  'CHE',
#  'PRT',
#  'CZE',
#  'SVN',
#  'IRL',
#  'NIC',
#  'DOM',
#  'FIN',
#  'MAR',
#  'NGA',
#  'LBN',
#  'COL',
#  'HRV',
#  'LTU',
#  'LAO',
#  'CRI',
#  'BOL',
#  'COG',
#  'ARG',
#  'GRC',
#  'PER',
#  'FRA',
#  'LVA',
#  'MDA',
#  'SWE',
#  'CAN',
#  'BEL',
#  'USA',
#  'NLD',
#  'NAM',
#  'DNK',
#  'JPN',
#  'AGO',
#  'MNG',
#  'URY',
#  'MUS',
#  'KAZ',
#  'SAU',
#  'OMN',
#  'ARE',
#  'NZL',
#  'RUS',
#  'IRN',
#  'KWT',
#  'MKD',
#  'JAM',
#  'ECU',
#  'CHL',
#  'GAB',
#  'TKM',
#  'ITA',
#  'ALB',
#  'GEO',
#  'NOR',
#  'DZA',
#  'VEN',
#  'AUT',
#  'AZE',
#  'BWA',
#  'QAT',
#  'AUS',
#  'LBY',
#  'CUB',
#  'DEU',
#  'TTO',
#  'SYR',
#  'IND',
#  'UGA',
#  'KEN',
#  'TZA',
#  'EGY',
#  'MDG',
#  'SEN',
#  'PHL',
#  'MWI',
#  'ZMB',
#  'GTM',
#  'PAK',
#  'ZWE',
#  'MYS',
#  'IDN',
#  'JOR',
#  ...]

# %%
# Discard countries with missing values
df = df.query("iso not in ['SRB', 'SYR']")

# %%
# Generates unique countries ranks for each year with no gaps
df['rank'] = df.groupby('year')['value'].rank(ascending=False, method='first')

# %%
# Convert rank to integer
df['rank'] = df['rank'].apply(lambda x: int(x))

# %%
# Make sure the ranks are sorted from 1 to Max
df.sort(['rank'], ascending=False);

# %%
# Preview of the resulting rankings
df.head()
# Out:
#    iso  year  value  rank
# 0  IND  2004   7.15     1
# 1  UGA  2004   6.11     3
# 2  KEN  2004   6.32     2
# 3  TZA  2004   6.11     4
# 4  EGY  2004   5.00    14

# %%
df = pd.merge(df, df_countries[['cca3', 'name.common']], how='left', left_on='iso', right_on='cca3')
df.pop('cca3');

# %%
df = df.rename(columns = {'name.common':'name'})
df.head()
# Out:
#    iso  year  value  rank      name
# 0  IND  2004   7.15     1     India
# 1  UGA  2004   6.11     3    Uganda
# 2  KEN  2004   6.32     2     Kenya
# 3  TZA  2004   6.11     4  Tanzania
# 4  EGY  2004   5.00    14     Egypt

# %%
# Export
url_export_projections = '/Users/rvuillemot/Dev/vis-toolkit-datasets/data/atlas_growth_projections_2024.csv'
df_export = df[['rank', 'value', 'name', 'iso', 'year']]
df_export.to_csv(url_export_projections, index=False)

# %% [markdown]
# ## Load ECI data

# %%
df_eci = pd.read_csv(file_rank_eci)
df_eci.head()
# Out:
#    iso  rank_eci2003  rank_eci2004  rank_eci2005  rank_eci2006  rank_eci2007  \
# 0  JPN             1             1             1             1             1
# 1  DEU             2             2             2             2             2
# 2  CHE             3             4             3             4             3
# 3  KOR            17            15             9            10             9
# 4  SWE             4             3             4             3             4
#
#    rank_eci2008  rank_eci2009  rank_eci2010  rank_eci2011  rank_eci2012  \
# 0             1             1             1             1             1
# 1             2             2             3             3             3
# 2             3             3             2             2             2
# 3             9             9             8             8             4
# 4             4             4             5             4             5
#
#    rank_eci2013  rank_eci2014
# 0             1             1
# 1             2             2
# 2             3             3
# 3             4             4
# 4             5             5

# %%
# Turning temporal columns into rows+year
df_eci = pd.melt(df_eci, id_vars=["iso"], var_name="year", value_name="rank_eci")
df_eci.head()
# Out:
#    iso          year  rank_eci
# 0  JPN  rank_eci2003         1
# 1  DEU  rank_eci2003         2
# 2  CHE  rank_eci2003         3
# 3  KOR  rank_eci2003        17
# 4  SWE  rank_eci2003         4

# %%
# Formatting year (time) column
for index, row in df_eci.iterrows():
    df_eci.loc[index, "year"] = df_eci.loc[index, "year"][8:]
df_eci.head()
# Out:
#    iso  year  rank_eci
# 0  JPN  2003         1
# 1  DEU  2003         2
# 2  CHE  2003         3
# 3  KOR  2003        17
# 4  SWE  2003         4

# %%
# Merging with countries metadata
df_eci_countries = pd.merge(df_eci, df_countries[['cca3', 'name.common']], how='left', left_on='iso', right_on='cca3')

# %%
df_eci_countries.pop('cca3');

# %%
df_eci_countries = df_eci_countries.rename(columns = {'name.common':'name'})

# %%
# Discard countries that don't have data for every time point between 2004 and 2014
countries_null = list(set(df_eci_countries[df_eci_countries['rank_eci'].isnull()]['iso']))
countries_null
# Out:
# ['SRB']

# %%
df_eci_countries = df_eci_countries.query("iso not in ['SRB']")

# %%
df_eci_countries['rank_eci'] = df_eci_countries['rank_eci'].apply(lambda x: int(x))
df_eci_countries.head()
# Out:
#    iso  year  rank_eci         name
# 0  JPN  2003         1        Japan
# 1  DEU  2003         2      Germany
# 2  CHE  2003         3  Switzerland
# 3  KOR  2003        17  South Korea
# 4  SWE  2003         4       Sweden

# %%
df_export = df[['rank', 'name', 'iso']]
url_rankings = '/Users/rvuillemot/Dev/atlas-economic-complexity/media/growth_projections/country_rankings_and_projections_2014.csv'
df_export.to_csv(url_rankings, index = False)

# %% [markdown]
# # Merge Projections and ECI Rankings to generate export file
#
# Will go on the sidebar for the page http://beta.atlas.cid.harvard.edu/rankings/
#
# Data for 2013 predictions: http://atlas.cid.harvard.edu/media/growth_projections/country_rankings_and_projections_2013.csv has the format below
#
# <pre>
# rank,abbrv,country,eci_value,delta,year,growth_proj_annual_2024
# 1,JPN,Japan,2.348182,0,2013,2.13
# 2,CHE,Switzerland,2.331362,0,2013,3.62
# 3,DEU,Germany,2.03559,0,2013,-1.33
# 4,KOR,"Korea, Rep.",1.92968,1,2013,3.85
# 5,SWE,Sweden,1.817256,-1,2013,2.6
# </pre>

# %%
df_merge = pd.merge(df_eci, df, how='inner', left_on=['iso', 'year'], right_on=['iso', 'year'])

# %%
df_merge = df_merge.rename(columns = {'rank':'rank_growth', 'value': 'growth_proj_annual_2024'})
df_merge['rank_eci'] = df_merge['rank_eci'].apply(lambda x: int(x))
df_merge.head()
# Out:
#    iso  year  rank_eci  growth_proj_annual_2024  rank_growth         name
# 0  JPN  2004         1                     3.69           47        Japan
# 1  DEU  2004         2                     1.38          118      Germany
# 2  CHE  2004         4                     3.54           53  Switzerland
# 3  KOR  2004        15                     3.60           51  South Korea
# 4  SWE  2004         3                     3.92           38       Sweden

# %%
url_rankings = '/Users/rvuillemot/Dev/atlas-economic-complexity/media/growth_projections/country_rankings_and_projections_2014.csv'
df_merge.to_csv(url_rankings, index = False)

# %% [markdown]
# # Generate HTML static table
#
#
#       <tr class="news__tr">
#         <td class="news__td news__td--categorical">1</td>
#         <td class="news__td news__td--categorial">India</td>
#         <td class="news__td news__td--quantitative">7.89</td>
#       </tr>

# %%
for row in df[(df['year'] == '2014')].iterrows():
    print("<tr class=\"news__tr\">")
    print("\t<td class=\"news__td news__td--categorical\">%s</td>" % (row[1][3]))
    print("\t<td class=\"news__td news__td--categorial\">%s</td>" % (row[1][4]))
    print("\t<td class=\"news__td news__td--quantitative\">%s</td>" % (row[1][2]))
    print("</tr>")
# Out:
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">1</td>
# 	<td class="news__td news__td--categorial">India</td>
# 	<td class="news__td news__td--quantitative">6.98</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">2</td>
# 	<td class="news__td news__td--categorial">Uganda</td>
# 	<td class="news__td news__td--quantitative">6.04</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">3</td>
# 	<td class="news__td news__td--categorial">Kenya</td>
# 	<td class="news__td news__td--quantitative">6.0</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">4</td>
# 	<td class="news__td news__td--categorial">Tanzania</td>
# 	<td class="news__td news__td--quantitative">5.96</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">5</td>
# 	<td class="news__td news__td--categorial">Egypt</td>
# 	<td class="news__td news__td--quantitative">5.83</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">6</td>
# 	<td class="news__td news__td--categorial">Madagascar</td>
# 	<td class="news__td news__td--quantitative">5.78</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">7</td>
# 	<td class="news__td news__td--categorial">Senegal</td>
# 	<td class="news__td news__td--quantitative">5.77</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">8</td>
# 	<td class="news__td news__td--categorial">Philippines</td>
# 	<td class="news__td news__td--quantitative">5.68</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">9</td>
# 	<td class="news__td news__td--categorial">Malawi</td>
# 	<td class="news__td news__td--quantitative">5.66</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">10</td>
# 	<td class="news__td news__td--categorial">Zambia</td>
# 	<td class="news__td news__td--quantitative">5.55</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">11</td>
# 	<td class="news__td news__td--categorial">Guatemala</td>
# 	<td class="news__td news__td--quantitative">5.22</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">12</td>
# 	<td class="news__td news__td--categorial">Pakistan</td>
# 	<td class="news__td news__td--quantitative">5.07</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">13</td>
# 	<td class="news__td news__td--categorial">Zimbabwe</td>
# 	<td class="news__td news__td--quantitative">4.93</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">14</td>
# 	<td class="news__td news__td--categorial">Malaysia</td>
# 	<td class="news__td news__td--quantitative">4.87</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">15</td>
# 	<td class="news__td news__td--categorial">Indonesia</td>
# 	<td class="news__td news__td--quantitative">4.82</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">16</td>
# 	<td class="news__td news__td--categorial">Jordan</td>
# 	<td class="news__td news__td--quantitative">4.81</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">17</td>
# 	<td class="news__td news__td--categorial">Vietnam</td>
# 	<td class="news__td news__td--quantitative">4.75</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">18</td>
# 	<td class="news__td news__td--categorial">Mali</td>
# 	<td class="news__td news__td--quantitative">4.71</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical
td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">101</td>
# 	<td class="news__td news__td--categorial">Macedonia</td>
# 	<td class="news__td news__td--quantitative">1.94</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">102</td>
# 	<td class="news__td news__td--categorial">Jamaica</td>
# 	<td class="news__td news__td--quantitative">1.92</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">103</td>
# 	<td class="news__td news__td--categorial">Ecuador</td>
# 	<td class="news__td news__td--quantitative">1.91</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">104</td>
# 	<td class="news__td news__td--categorial">Chile</td>
# 	<td class="news__td news__td--quantitative">1.89</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">105</td>
# 	<td class="news__td news__td--categorial">Gabon</td>
# 	<td class="news__td news__td--quantitative">1.85</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">106</td>
# 	<td class="news__td news__td--categorial">Turkmenistan</td>
# 	<td class="news__td news__td--quantitative">1.84</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">107</td>
# 	<td class="news__td news__td--categorial">Italy</td>
# 	<td class="news__td news__td--quantitative">1.83</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">108</td>
# 	<td class="news__td news__td--categorial">Albania</td>
# 	<td class="news__td news__td--quantitative">1.83</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">109</td>
# 	<td class="news__td news__td--categorial">Georgia</td>
# 	<td class="news__td news__td--quantitative">1.83</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">110</td>
# 	<td class="news__td news__td--categorial">Norway</td>
# 	<td class="news__td news__td--quantitative">1.73</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">111</td>
# 	<td class="news__td news__td--categorial">Algeria</td>
# 	<td class="news__td news__td--quantitative">1.71</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">112</td>
# 	<td class="news__td news__td--categorial">Venezuela</td>
# 	<td class="news__td news__td--quantitative">1.7</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">113</td>
# 	<td class="news__td news__td--categorial">Austria</td>
# 	<td class="news__td news__td--quantitative">1.66</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">114</td>
# 	<td class="news__td news__td--categorial">Azerbaijan</td>
# 	<td class="news__td news__td--quantitative">1.55</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">115</td>
# 	<td class="news__td news__td--categorial">Botswana</td>
# 	<td class="news__td news__td--quantitative">1.39</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">116</td>
# 	<td class="news__td news__td--categorial">Qatar</td>
# 	<td class="news__td news__td--quantitative">1.13</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">117</td>
# 	<td class="news__td news__td--categorial">Australia</td>
# 	<td class="news__td news__td--quantitative">1.07</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">118</td>
# 	<td class="news__td news__td--categorial">Libya</td>
# 	<td class="news__td news__td--quantitative">1.04</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">119</td>
# 	<td class="news__td news__td--categorial">Cuba</td>
# 	<td class="news__td news__td--quantitative">0.95</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">120</td>
# 	<td class="news__td news__td--categorial">Germany</td>
# 	<td class="news__td news__td--quantitative">0.35</td>
# </tr>
# <tr class="news__tr">
# 	<td class="news__td news__td--categorical">121</td>
# 	<td class="news__td news__td--categorial">Trinidad and Tobago</td>
# 	<td class="news__td news__td--quantitative">0.27</td>
# </tr>

# %% [markdown]
# # Projections of GDP Growth to 2024 Rankings: Selected Top Countries

# %%
# from IPython.display import display, HTML
# HTML(df.head().to_html())
df.to_csv('/Users/rvuillemot/Dev/vis-toolkit-datasets/data/atlas_growth_projections_2024.csv')

# %%
# Generate a pretty table
from ipy_table import *
import numpy as np

df_table = df[(df['year'] == '2014')].head(10).reset_index(drop=True).reset_index()
df_table = df_table[['rank', 'name', 'value']]
table = df_table.as_matrix()

header = np.asarray(df_table.columns)
header[0] = 'Rank'
header[2] = 'Value'
# df.rename(columns=lambda x: x[1:], inplace=True)
table_with_header = np.concatenate(([header], table))

# Basic themes
# Detais http://nbviewer.ipython.org/github/epmoyer/ipy_table/blob/master/ipy_table-Introduction.ipynb
make_table(table_with_header)
apply_theme('basic')
# Only show the top-10
set_row_style(1, color='yellow')
# Out:
# <table border="1" cellpadding="3" cellspacing="0"  style="border:1px solid black;border-collapse:collapse;"><tr><td  style="background-color:LightGray;"><b>Rank</b></td><td  style="background-color:LightGray;"><b>name</b></td><td  style="background-color:LightGray;"><b>Value</b></td></tr><tr><td  style="background-color:yellow;">1</td><td  style="background-color:yellow;">India</td><td  style="background-color:yellow;">6.98</td></tr><tr><td  style="background-color:AliceBlue;">2</td><td  style="background-color:AliceBlue;">Uganda</td><td  style="background-color:AliceBlue;">6.04</td></tr><tr><td  style="background-color:Ivory;">3</td><td  style="background-color:Ivory;">Kenya</td><td  style="background-color:Ivory;">6.0</td></tr><tr><td  style="background-color:AliceBlue;">4</td><td  style="background-color:AliceBlue;">Tanzania</td><td  style="background-color:AliceBlue;">5.96</td></tr><tr><td  style="background-color:Ivory;">5</td><td  style="background-color:Ivory;">Egypt</td><td  style="background-color:Ivory;">5.83</td></tr><tr><td  style="background-color:AliceBlue;">6</td><td  style="background-color:AliceBlue;">Madagascar</td><td  style="background-color:AliceBlue;">5.78</td></tr><tr><td  style="background-color:Ivory;">7</td><td  style="background-color:Ivory;">Senegal</td><td  style="background-color:Ivory;">5.77</td></tr><tr><td  style="background-color:AliceBlue;">8</td><td  style="background-color:AliceBlue;">Philippines</td><td  style="background-color:AliceBlue;">5.68</td></tr><tr><td  style="background-color:Ivory;">9</td><td  style="background-color:Ivory;">Malawi</td><td  style="background-color:Ivory;">5.66</td></tr><tr><td  style="background-color:AliceBlue;">10</td><td  style="background-color:AliceBlue;">Zambia</td><td  style="background-color:AliceBlue;">5.55</td></tr></table>

# %% [markdown]
# # Projections of GDP Growth to 2024 Rankings: Full List of Countries

# %%
IFrame('https://cid-harvard.github.io/vis-toolkit/examples/barchart_vertical_projections.html', width=900, height=550)
# Out:
#         <iframe
#             width="900"
#             height="550"
#             src="https://cid-harvard.github.io/vis-toolkit/examples/barchart_vertical_projections.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Economic Complexity Index: Rank of Expected GDP Growth to 2024

# %%
IFrame('https://cid-harvard.github.io/vis-toolkit/examples/geomap_and_tick.html', width=900, height=500)
# Out:
#         <iframe
#             width="900"
#             height="500"
#             src="https://cid-harvard.github.io/vis-toolkit/examples/geomap_and_tick.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Biggest Winners and Losers in Economic Complexity: 2004-2014

# %%
IFrame('https://cid-harvard.github.io/vis-toolkit/examples/slopegraph_eci_rankings.html', width=900, height=550)
# Out:
#         <iframe
#             width="900"
#             height="550"
#             src="https://cid-harvard.github.io/vis-toolkit/examples/slopegraph_eci_rankings.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # Economic Complexity Index: 2004-2014 Country Rankings

# %%
IFrame('https://cid-harvard.github.io/vis-toolkit/examples/linechart_eci_rankings.html', width=900, height=550)
# Out:
#         <iframe
#             width="900"
#             height="550"
#             src="https://cid-harvard.github.io/vis-toolkit/examples/linechart_eci_rankings.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
